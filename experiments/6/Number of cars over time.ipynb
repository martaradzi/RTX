# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import plot, show, savefig, xlim, figure,  ylim, legend, boxplot, setp, axes

# %%
df = pd.read_csv('car_number.csv')

# %%
df.head()
# Out:
#    Hour  Number of Cars
# 0     0             450
# 1     1             520
# 2     2             600
# 3     3             350
# 4     4             200

# %%
dd = df.plot(y='Number of Cars', c='b', figsize= (17,5), grid=True, label = 'Number of Cars')
dd.set_ylabel("Number of Cars")
dd.set_xlabel("Time of the day")
dd.set_ylim(0, 780)
dd.set_xlim(0, 23)
# dd.set_title('Trends of traffic throughout the day')
# Out:
# (0.0, 23.0)
