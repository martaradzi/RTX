# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_number.csv')

# %%
ax = df.plot(y='Number of Cars',grid=True, figsize=(15,7))
ax.set_xlabel('Time')
ax.set_ylabel('Number of Cars')
# Out:
# Text(0, 0.5, 'Number of Cars')
