# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#     totalCarNumber  avg_overhead  std_overhead  var_overhead  median_overhead  \
# 0              200      1.688211      0.499817      0.249817         1.616976
# 1              300      2.281520      3.546109     12.574890         1.620352
# 2              400      2.571945      4.580152     20.977795         1.673686
# 3              500      2.669871      4.570045     20.885314         1.817703
# 4              600      2.830983      4.826046     23.290721         1.801535
# 5              700      2.876458      4.241746     17.992412         1.942154
# 6              800      3.173920      4.623891     21.380369         2.034481
# 7              900      3.024974      3.901572     15.222265         2.135608
# 8             1000      3.625510      5.114479     26.157900         2.174589
# 9             1100      3.430019      5.026497     25.265675         2.044256
# 10            1200      3.477903      4.812975     23.164730         2.124910
# ...

# %%
df.plot(x='totalCarNumber',y='duration', figsize=(10,10))
